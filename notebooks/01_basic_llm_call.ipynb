# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# Find and load .env explicitly
env_path = r"C:\Users\User\Desktop\micronprep\.env"
load_dotenv(env_path)

# Debug — check what's happening
print("Looking for .env at:", env_path)
print(".env exists:", os.path.exists(env_path))

api_key = os.environ.get("GROQ_API_KEY")
print("Key loaded:", "YES" if api_key else "NO")

client = OpenAI(
    api_key=api_key,
    base_url="https://api.groq.com/openai/v1"
)

messages = [
    {"role": "system", "content": "You are an SSD architecture assistant. Be concise and accurate."},
    {"role": "user",   "content": "What is the role of the Flash Translation Layer in an NVMe SSD?"}
]

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=messages,
    temperature=0.1,
    max_tokens=300
)

print("\nAnswer:\n", response.choices[0].message.content)
print("Tokens used:", response.usage.total_tokens)
# Out:
# Looking for .env at: C:\Users\User\Desktop\micronprep\.env
# .env exists: True
# Key loaded: YES
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 26
#      22     {"role": "system", "content": "You are an SSD architecture assistant. Be concise and accurate."},
#      23     {"role": "user",   "content": "What is the role of the Flash Translation Layer in an NVMe SSD?"}
#      24 ]
#      25
# ---> 26 response = client.chat.completions.create(
#      27     model="llama3-8b-8192",
#      28     messages=messages,
#      29     temperature=0.1,
#
# File c:\Users\User\Desktop\micronprep\.venv311\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...

# %%
# Cell 2 — few-shot log classifier
messages_fs = [
    {"role": "system", "content": "Classify SSD firmware logs. Respond ONLY as:\nSEVERITY: [INFO|WARNING|CRITICAL]\nREASON: [one sentence]\nACTION: [what to do]"},
    {"role": "user",      "content": "Log: NVMe queue depth at 80% capacity"},
    {"role": "assistant", "content": "SEVERITY: WARNING\nREASON: High queue depth indicates heavy I/O load.\nACTION: Monitor for further increase."},
    {"role": "user",      "content": "Log: SMART self-test completed, no errors"},
    {"role": "assistant", "content": "SEVERITY: INFO\nREASON: Routine test passed cleanly.\nACTION: No action required."},
    {"role": "user",      "content": "Log: Uncorrectable ECC error on block 0x3F2A, wear count 98%"},
]

resp = client.chat.completions.create(
    model="llama3-8b-8192",
    messages=messages_fs,
    temperature=0.0,
    max_tokens=100
)
result = resp.choices[0].message.content
print(result)

# Parse into dict
parsed = {}
for line in result.strip().split("\n"):
    if ":" in line:
        k, v = line.split(":", 1)
        parsed[k.strip()] = v.strip()
print("\nParsed dict:", parsed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       7     {"role": "assistant", "content": "SEVERITY: INFO\nREASON: Routine test passed cleanly.\nACTION: No action required."},
#       8     {"role": "user",      "content": "Log: Uncorrectable ECC error on block 0x3F2A, wear count 98%"},
#       9 ]
#      10
# ---> 11 resp = client.chat.completions.create(
#      12     model="llama3-8b-8192",
#      13     messages=messages_fs,
#      14     temperature=0.0,
#
# NameError: name 'client' is not defined
